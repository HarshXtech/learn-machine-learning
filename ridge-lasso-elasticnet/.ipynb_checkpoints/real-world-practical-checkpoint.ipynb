# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('insurance.csv')

# %%
# Preprocessing the data

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

df_encoded = pd.get_dummies(df, drop_first=True)

# %%
df_encoded
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes  \
# 0      19  27.900         0  16884.92400     False        True
# 1      18  33.770         1   1725.55230      True       False
# 2      28  33.000         3   4449.46200      True       False
# 3      33  22.705         0  21984.47061      True       False
# 4      32  28.880         0   3866.85520      True       False
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830      True       False
# 1334   18  31.920         0   2205.98080     False       False
# 1335   18  36.850         0   1629.83350     False       False
# 1336   21  25.800         0   2007.94500     False       False
# 1337   61  29.070         0  29141.36030     False        True
#
#       region_northwest  region_southeast  region_southwest
# 0                False             False              True
# 1                False              True             False
# ...

# %%
x = df_encoded.drop('charges', axis="columns")
y = df['charges']

# %%
x_scaled = scaler.fit_transform(x)

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet

# %%
models = {
    'Linear' : LinearRegression(),
    'Ridge' : Ridge(),
    'lasso' : Lasso(),
    'Elastic' : ElasticNet()
}
models.values()
# Out:
# dict_values([LinearRegression(), Ridge(), Lasso(), ElasticNet()])

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
import matplotlib.pyplot as plt
result = {}
plt.figure(figsize=(12, 8))
for name, model in models.items():
    model.fit(x_scaled, y)

    y_pred = model.predict(x_scaled)

    result[name] = {
        'name' : name,
        'mse' : mean_squared_error(y, y_pred),
        'mae' : mean_absolute_error(y, y_pred),
    }

    plt.scatter(y, y_pred, label=name, alpha=0.4)

minmum = min(min(y), min([min(model.predict(x_scaled)) for model in models.values()]))
maxmum = max(max(y), max([max(model.predict(x_scaled)) for model in models.values()]))
plt.plot([minmum, maxmum], [minmum, maxmum,] ,'k--' )
plt.tight_layout()
plt.legend()
plt.grid(True)
plt.show()

# %%
result
# Out:
# {'Linear': {'name': 'Linear',
#   'mse': 36501893.00741544,
#   'mae': 4170.886894163591},
#  'Ridge': {'name': 'Ridge', 'mse': 36501956.619647, 'mae': 4171.7526462923715},
#  'lasso': {'name': 'lasso', 'mse': 36501908.6676196, 'mae': 4170.782107802395},
#  'Elastic': {'name': 'Elastic',
#   'mse': 48817680.32306508,
#   'mae': 5105.807754482576}}
