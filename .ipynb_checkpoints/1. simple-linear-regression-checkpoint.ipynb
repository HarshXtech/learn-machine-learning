# %%
# Steps : 

# 1) devide features into dependent and independent features.
# 2) train test split of the dataset
# 3) Standerdize the data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('weight-height.csv')

# %%
plt.scatter(df['Weight'],df['Height'])
plt.xlabel('weight')
plt.ylabel('height')
# Out:
# Text(0, 0.5, 'height')

# %%
# 1) devide features into dependent and independent features.
df['Weight'] = df['Weight'].round().astype(int)
df['Height'] = df["Height"].astype(int)
x = df[['Weight']] # independent feature
y = df['Height'] # dependent feature

# %%
y
# Out:
# 0     73
# 1     68
# 2     74
# 3     71
# 4     69
#       ..
# 94    67
# 95    65
# 96    71
# 97    66
# 98    66
# Name: Height, Length: 99, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=.20, random_state=42)

# %%
x_train.shape
# Out:
# (79, 1)

# %%
# Standardize the training data

from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
scaler.fit_transform(x_train)
# Out:
# array([[ 1.56512377],
#        [ 0.        ],
#        [-0.39128094],
#        [-0.39128094],
#        [-1.95640471],
#        [ 0.        ],
#        [-2.34768565],
#        [-0.39128094],
#        [ 1.17384282],
#        [-1.56512377],
#        [-0.78256188],
#        [ 0.        ],
#        [-0.78256188],
#        [ 1.17384282],
#        [-0.78256188],
#        [ 0.39128094],
#        [ 0.        ],
#        [ 0.39128094],
#        [ 1.17384282],
#        [ 0.39128094],
#        [ 0.39128094],
#        [-0.39128094],
#        [-1.17384282],
#        [ 1.56512377],
#        [-0.39128094],
#        [-0.39128094],
#        [-0.39128094],
#        [-0.78256188],
#        [ 0.        ],
#        [-0.39128094],
#        [ 1.17384282],
#        [-1.95640471],
#        [-1.17384282],
#        [-0.78256188],
#        [ 1.17384282],
#        [ 0.        ],
#        [-1.17384282],
#        [ 0.        ],
#        [-1.56512377],
#        [-0.39128094],
#        [-1.17384282],
# ...
